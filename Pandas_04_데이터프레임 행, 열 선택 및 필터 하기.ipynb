# %%
import pandas as pd

# %%
friend_dict_list = [
         {'name': 'Jone', 'age': 20, 'job': 'student'},
         {'name': 'Jenny', 'age': 30, 'job': None},
         {'name': 'Nate', 'age': 30, 'job': 'teacher'}
]

# %%
df = pd.DataFrame(friend_dict_list)

# %%
df
# Out:
#     name  age      job
# 0   Jone   20  student
# 1  Jenny   30     None
# 2   Nate   30  teacher

# %%
df.loc[ [0,2] ]
# Out:
#    name  age      job
# 0  Jone   20  student
# 2  Nate   30  teacher

# %%
df[1:3]
# Out:
#     name  age      job
# 1  Jenny   30     None
# 2   Nate   30  teacher

# %% [markdown]
# ### by column condition

# %%
df[df.age > 25]
# Out:
#     name  age      job
# 1  Jenny   30     None
# 2   Nate   30  teacher

# %%
df.query('age>25')
# Out:
#     name  age      job
# 1  Jenny   30     None
# 2   Nate   30  teacher

# %%
df[ (df.age>25) & (df.name == 'Nate')]
# Out:
#    name  age      job
# 2  Nate   30  teacher

# %% [markdown]
# ## Filter Column

# %% [markdown]
# ### by index

# %%
friend_list = [ ['John', 20, 'student'],['Jenny', 30, 'developer'],['Nate', 30, 'teacher'] ]

# %%
df = pd.DataFrame.from_records(friend_list)

# %%
df
# Out:
#        0   1          2
# 0   John  20    student
# 1  Jenny  30  developer
# 2   Nate  30    teacher

# %%
df.iloc[:,0:2]
# Out:
#        0   1
# 0   John  20
# 1  Jenny  30
# 2   Nate  30

# %% [markdown]
# ## by column name

# %%
df = pd.read_csv('sample_data/friend_list_no_head.csv', header= None, names=['name', 'age', 'job'])

# %%
df
# Out:
#     name  age        job
# 0   John   20    student
# 1  Jenny   30  developer
# 2   Nate   30    teacher
# 3  Julia   40    dentist
# 4  Brian   45    manager
# 5  Chris   25     intern

# %%
df_filtered = df[['name', 'age']]

# %%
df_filtered
# Out:
#     name  age
# 0   John   20
# 1  Jenny   30
# 2   Nate   30
# 3  Julia   40
# 4  Brian   45
# 5  Chris   25

# %%
df.filter(items=['age', 'job'])
# Out:
#    age        job
# 0   20    student
# 1   30  developer
# 2   30    teacher
# 3   40    dentist
# 4   45    manager
# 5   25     intern

# %%
df.filter(like='a', axis=1)
# Out:
#     name  age
# 0   John   20
# 1  Jenny   30
# 2   Nate   30
# 3  Julia   40
# 4  Brian   45
# 5  Chris   25

# %% [markdown]
# column 중 'a'가 들어가는 것만 고르기
#
# column이니까 axis=1
