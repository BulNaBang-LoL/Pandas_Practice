# %% [markdown]
# ### how to use map function

# %%
import pandas as pd

# %%
date_list = [{'yyyy-mm-dd': '2000-06-27'},
         {'yyyy-mm-dd': '2002-09-24'},
         {'yyyy-mm-dd': '2005-12-20'}]

# %%
df = pd.DataFrame(date_list, columns = ['yyyy-mm-dd'])

# %%
df
# Out:
#    yyyy-mm-dd
# 0  2000-06-27
# 1  2002-09-24
# 2  2005-12-20

# %%
def extract_year(date):
    return date.split('-')[0]

# %%
df['year'] = df['yyyy-mm-dd'].map(extract_year)

# %% [markdown]
# apply 함수와 동일한 방법으로 map 사용.
#
# 하지만 map은 이외에도 다양한 기능이 있다.

# %%
df
# Out:
#    yyyy-mm-dd  year
# 0  2000-06-27  2000
# 1  2002-09-24  2002
# 2  2005-12-20  2005

# %%
job_list = [{'age': 20, 'job': 'student'},
         {'age': 30, 'job': 'developer'},
         {'age': 30, 'job': 'teacher'}]

# %%
df = pd.DataFrame(job_list)

# %%
df
# Out:
#    age        job
# 0   20    student
# 1   30  developer
# 2   30    teacher

# %%
df.job = df.job.map({"student":1,"developer":2,"teacher":3})

# %%
df
# Out:
#    age  job
# 0   20    1
# 1   30    2
# 2   30    3

# %% [markdown]
# ### Applymap
# update all elements in the dataframe at once

# %%
x_y = [{'x': 5.5, 'y': -5.6},
         {'x': -5.2, 'y': 5.5},
         {'x': -1.6, 'y': -4.5}]

# %%
df = pd.DataFrame(x_y)

# %%
df
# Out:
#      x    y
# 0  5.5 -5.6
# 1 -5.2  5.5
# 2 -1.6 -4.5

# %%
import numpy as np

# %%
df = df.applymap(np.around)

# %%
df
# Out:
#      x    y
# 0  6.0 -6.0
# 1 -5.0  6.0
# 2 -2.0 -4.0
